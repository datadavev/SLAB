# %% [markdown]
# # Evaluating bioontology search
#
# data.bioontology.org is used as a service for resolving terms through a search mechanism.
#
# ```
# https://data.bioontology.org/search?q=co2*&apikey=5c385237-ec28-4ef6-8ba1-f5bcfb752142&no_context=true&ontologies=ECSO&subtree_id=http%3A%2F%2Fecoinformatics.org%2Foboe%2Foboe.1.2%2Foboe-core.owl%23MeasurementType&ontology=ECSO&pagesize=100
# ```

# %%
import requests
import json
from prettytable import PrettyTable
import pandas as pd
from pprint import pprint 

def generate_ascii_table(df):
    x = PrettyTable()
    x.field_names = df.columns.tolist()
    for fld in x.field_names:
        x.align[fld] = "l"
    for row in df.values:
        x.add_row(row)
    return x

def getResultsAscTable(response):
    data = json.loads(response.text)
    pprint(data)
    table = []
    i = 0
    for item in data["collection"]:
        row = [i, item["prefLabel"], ]
        row.append(", ".join(['"{0}"'.format(x) for x in item.get("synonym", [])]))
        table.append(row)
        i += 1
    df = pd.DataFrame(table, columns=["#", "prefLabel", "Synonyms"])
    return generate_ascii_table(df)

bio_url = "https://data.bioontology.org/property_search"

params = {
    "apikey":"5c385237-ec28-4ef6-8ba1-f5bcfb752142",
    "no_context":"true",
#    "ontologies":"ECSO",
    "subtree_id": "http://ecoinformatics.org/oboe/oboe.1.2/oboe-core.owl#MeasurementType",
    "ontology":"ECSO",
    "pagesize": 100,
    "suggest":"true",
#    "require_definitions":"true",
#    "require_exact_match":"true",
    "q":""
}

# %%
params['q'] = "carbon dioxide flux"
response = requests.get(bio_url, params=params)
print(f"Search for: \"{params['q']}\"")
print(getResultsAscTable(response))
# Out:
# Search for: "carbon dioxide flux"
# {'collection': [{'@id': 'http://www.projecthalo.com/aura#luminous-flux',
#                  '@type': 'http://www.w3.org/2002/07/owl#ObjectProperty',
#                  'labelGenerated': ['luminous-flux', 'luminous flux'],
#                  'links': {'ancestors': 'http://data.bioontology.org/ontologies/AURA/properties/http%3A%2F%2Fwww.projecthalo.com%2Faura%23luminous-flux/ancestors',
#                            'children': 'http://data.bioontology.org/ontologies/AURA/properties/http%3A%2F%2Fwww.projecthalo.com%2Faura%23luminous-flux/children',
#                            'descendants': 'http://data.bioontology.org/ontologies/AURA/properties/http%3A%2F%2Fwww.projecthalo.com%2Faura%23luminous-flux/descendants',
#                            'ontology': 'http://data.bioontology.org/ontologies/AURA',
#                            'parents': 'http://data.bioontology.org/ontologies/AURA/properties/http%3A%2F%2Fwww.projecthalo.com%2Faura%23luminous-flux/parents',
#                            'self': 'http://data.bioontology.org/ontologies/AURA/properties/http%3A%2F%2Fwww.projecthalo.com%2Faura%23luminous-flux',
#                            'submission': 'http://data.bioontology.org/ontologies/AURA/submissions/1',
#                            'tree': 'http://data.bioontology.org/ontologies/AURA/properties/http%3A%2F%2Fwww.projecthalo.com%2Faura%23luminous-flux/tree'},
#                  'matchType': 'labelGenerated',
#                  'ontologyType': 'ONTOLOGY',
#                  'propertyType': 'OBJECT'},
#                 {'@id': 'http://sweetontology.net/relaPhysical/hasEnergyFlux',
#                  '@type': 'http://www.w3.org/2002/07/owl#AnnotationProperty',
#                  'label': ['has energy flux'],
#                  'labelGenerated': ['hasenergyflux'],
#                  'links': {'ancestors': 'http://data.bioontology.org/ontologies/SWEET/properties/http%3A%2F%2Fsweetontology.net%2FrelaPhysical%2FhasEnergyFlux/ancestors',
#                            'children': 'http://data.bioontology.org/ontologies/SWEET/properties/http%3A%2F%2Fsweetontology.net%2FrelaPhysical%2FhasEnergyFlux/children',
#                            'descendants': 'http://data.bioontology.org/ontologies/SWEET/properties/http%3A%2F%2Fsweetontology.net%2FrelaPhysical%2FhasEnergyFlux/descendants',
#                            'ontology': 'http://data.bioontology.org/ontologies/SWEET',
#                            'parents': 'http://data.bioontology.org/ontologies/SWEET/properties/http%3A%2F%2Fsweetontology.net%2FrelaPhysical%2FhasEnergyFlux/parents',
#                            'self': 'http://data.bioontology.org/ontologies/SWEET/properties/http%3A%2F%2Fsweetontology.net%2FrelaPhysical%2FhasEnergyFlux',
#                            'submission': 'http://data.bioontology.org/ontologies/SWEET/submissions/5',
#                            'tree': 'http://data.bioontology.org/ontologies/SWEET/properties/http%3A%2F%2Fsweetontology.net%2FrelaPhysical%2FhasEnergyFlux/tree'},
#                  'matchType': 'label',
#                  'ontologyType': 'ONTOLOGY',
#                  'propertyType': 'ANNOTATION'},
#                 {'@id': 'http://glycomics.ccrc.uga.edu/ontologies/GlycO#has_anomeric_carbon',
#                  '@type': 'http://www.w3.org/2002/07/owl#ObjectProperty',
#                  'label': ['has anomeric carbon'],
#                  'labelGenerated': ['has_anomeric_carbon'],
#                  'links': {'ancestors': 'http://data.bioontology.org/ontologies/GLYCO/properties/http%3A%2F%2Fglycomics.ccrc.uga.edu%2Fontologies%2FGlycO%23has_anomeric_carbon/ancestors',
#                            'children': 'http://data.bioontology.org/ontologies/GLYCO/properties/http%3A%2F%2Fglycomics.ccrc.uga.edu%2Fontologies%2FGlycO%23has_anomeric_carbon/children',
#                            'descendants': 'http://data.bioontology.org/ontologies/GLYCO/properties/http%3A%2F%2Fglycomics.ccrc.uga.edu%2Fontologies%2FGlycO%23has_anomeric_carbon/descendants',
#                            'ontology': 'http://data.bioontology.org/ontologies/GLYCO',
#                            'parents': 'http://data.bioontology.org/ontologies/GLYCO/properties/http%3A%2F%2Fglycomics.ccrc.uga.edu%2Fontologies%2FGlycO%23has_anomeric_carbon/parents',
#                            'self': 'http://data.bioontology.org/ontologies/GLYCO/properties/http%3A%2F%2Fglycomics.ccrc.uga.edu%2Fontologies%2FGlycO%23has_anomeric_carbon',
#                            'submission': 'http://data.bioontology.org/ontologies/GLYCO/submissions/1',
#                            'tree': 'http://data.bioontology.org/ontologies/GLYCO/properties/http%3A%2F%2Fglycomics.ccrc.uga.edu%2Fontologies%2FGlycO%23has_anomeric_carbon/tree'},
#                  'matchType': 'label',
#                  'ontologyType': 'ONTOLOGY',
#                  'parents': ['http://glycomics.ccrc.uga.edu/ontologies/GlycO#has_structural_property'],
#                  'propertyType': 'OBJECT'},
#                 {'@id': 'http://purl.jp/bio/12/glyco/glycan#of_carbon_number',
#                  '@type': 'http://www.w3.org/2002/07/owl#DatatypeProperty',
#                  'definition': ['carbon atom number'],
#                  'labelGenerated': ['of_carbon_number', 'of carbon number'],
#                  'links': {'ancestors': 'http://data.bioontology.org/ontologies/GLYCORDF/properties/http%3A%2F%2Fpurl.jp%2Fbio%2F12%2Fglyco%2Fglycan%23of_carbon_number/ancestors',
#                            'children': 'http://data.bioontology.org/ontologies/GLYCORDF/properties/http%3A%2F%2Fpurl.jp%2Fbio%2F12%2Fglyco%2Fglycan%23of_carbon_number/children',
#                            'descendants': 'http://data.bioontology.org/ontologies/GLYCORDF/properties/http%3A%2F%2Fpurl.jp%2Fbio%2F12%2Fglyco%2Fglycan%23of_carbon_number/descendants',
#                            'ontology': 'http://data.bioontology.org/ontologies/GLYCORDF',
#                            'parents': 'http://data.bioontology.org/ontologies/GLYCORDF/properties/http%3A%2F%2Fpurl.jp%2Fbio%2F12%2Fglyco%2Fglycan%23of_carbon_number/parents',
#                            'self': 'http://data.bioontology.org/ontologies/GLYCORDF/properties/http%3A%2F%2Fpurl.jp%2Fbio%2F12%2Fglyco%2Fglycan%23of_carbon_number',
#                            'submission': 'http://data.bioontology.org/ontologies/GLYCORDF/submissions/56',
#                            'tree': 'http://data.bioontology.org/ontologies/GLYCORDF/properties/http%3A%2F%2Fpurl.jp%2Fbio%2F12%2Fglyco%2Fglycan%23of_carbon_number/tree'},
#                  'matchType': 'labelGenerated',
#                  'ontologyType': 'ONTOLOGY',
#                  'propertyType': 'DATATYPE'}],
#  'links': {'nextPage': None, 'prevPage': None},
#  'nextPage': None,
#  'page': 1,
#  'pageCount': 1,
#  'prevPage': None,
#  'totalCount': 4}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-bfe8c035ba5e> in <module>
#       2 response = requests.get(bio_url, params=params)
#       3 print(f"Search for: \"{params['q']}\"")
# ----> 4 print(getResultsAscTable(response))
#
# <ipython-input-7-b581f9c3551a> in getResultsAscTable(response)
#      20     i = 0
#      21     for item in data["collection"]:
# ---> 22         row = [i, item["prefLabel"], ]
#      23         row.append(", ".join(['"{0}"'.format(x) for x in item.get("synonym", [])]))
#      24         table.append(row)
#
# KeyError: 'prefLabel'

# %%
params['q'] = "co2 flux"
response = requests.get(bio_url, params=params)
print(f"Search for: \"{params['q']}\"")
print(getResultsAscTable(response))
# Out:
# Search for: "co2+flux"
# +----+------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------+
# | #  | prefLabel                                                        | Synonyms                                                                                                                        |
# +----+------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------+
# | 0  | Radiative flux                                                   | "Energy Flux", "Flux"                                                                                                           |
# | 1  | Carbon Dioxide Flux                                              | "CO2 Flux"                                                                                                                      |
# | 2  | Carbon Dioxide Diffusion Flux                                    | "CO2 Diffusion Flux"                                                                                                            |
# | 3  | Marine Macroalgae Net Primary Production Carbon Flux             | "Marine Macroalgae NPP Carbon Flux"                                                                                             |
# | 4  | outgoing photosynthetically active radiation                     | "reflected PAR", "outgoing photosynthetic photon flux density", "reflected photosynthetically active radiation", "outgoing PAR" |
# | 5  | Ground Heat Flux                                                 | "soil heat flux"                                                                                                                |
# | 6  | gap-filled or measured carbon dioxide flux                       | "gap-filled or measured CO2 flux"                                                                                               |
# | 7  | incoming photosynthetically active radiation                     | "incoming PAR", "incoming photosynthetic photon flux density"                                                                   |
# | 8  | Aboveground Net Primary Production Carbon Flux                   | "Aboveground NPP Carbon Flux"                                                                                                   |
# | 9  | Methane Flux                                                     | "CH4 Flux"                                                                                                                      |
# | 10 | Oceanic Carbon Dioxide Flux                                      | "Oceanic CO2 Flux"                                                                                                              |
# | 11 | soil carbon dioxide flux                                         | "soil CO2 flux"                                                                                                                 |
# | 12 | Grassland Above Ground Net Primary Production Carbon Flux        | "Grassland Above Ground NPP Carbon Flux", "anpp"                                                                                |
# | 13 | photosynthetically active radiation                              | "photosynthetic photon flux density", "PAR"                                                                                     |
# | 14 | correction factor for carbon dioxide flux                        | "correction factor for CO2 flux"                                                                                                |
# | 15 | Carbon Flux                                                      | "Mass Flux"                                                                                                                     |
# | 16 | Primary Production Carbon Flux                                   | "Primary production", "Primary productivity", "primary productivity"                                                            |
# | 17 | Flux Measurement Type                                            | "Flow Measurement Type"                                                                                                         |
# | 18 | Specific Gross Production Flux                                   |                                                                                                                                 |
# | 19 | carbon flux standard error                                       |                                                                                                                                 |
# | 20 | momentum flux mean error                                         |                                                                                                                                 |
# | 21 | kinematic flux                                                   |                                                                                                                                 |
# | 22 | Net Ecosystem Exchange Carbon Flux                               | "Net Ecosystem Exchange", "NEE"                                                                                                 |
# | 23 | nitrous oxide flux                                               |                                                                                                                                 |
# | 24 | Momentum Flux                                                    | "tau"                                                                                                                           |
# | 25 | sediment flux                                                    |                                                                                                                                 |
# | 26 | Net Carbon Respiration Rate Flux                                 |                                                                                                                                 |
# | 27 | Latent Heat Flux                                                 |                                                                                                                                 |
# | 28 | Gross Primary Production Carbon Flux                             | "GPP", "Gross primary productivity", "Gross Primary Production", "Gross Primary Productivity"                                   |
# | 29 | Fire Carbon Flux                                                 | "Fire Emissions"                                                                                                                |
# | 30 | Phytoplankton Primary Production Carbon Flux                     | "phytoplankton primary productivity"                                                                                            |
# | 31 | luminous flux                                                    |                                                                                                                                 |
# | 32 | coefficient of variation of exponential fit for soil carbon flux |                                                                                                                                 |
# | 33 | latent heat turbulent flux                                       |                                                                                                                                 |
# | 34 | coefficient of variation of linear fit for soil carbon flux      |                                                                                                                                 |
# | 35 | vertical salt flux                                               |                                                                                                                                 |
# | 36 | momentum flux uncertainty                                        |                                                                                                                                 |
# | 37 | latent heat storage flux                                         |                                                                                                                                 |
# | 38 | carbon flux exponential fit slope                                |                                                                                                                                 |
# | 39 | respiration carbon flux standard error                           |                                                                                                                                 |
# | 40 | Specific Respiration Flux                                        |                                                                                                                                 |
# | 41 | Heterotrophic Respiration Carbon Flux                            | "Heterotrophic Respiration"                                                                                                     |
# | 42 | carbon monoxide flux                                             |                                                                                                                                 |
# | 43 | net ecosystem exchange carbon flux standard deviation            |                                                                                                                                 |
# | 44 | Specific Flux                                                    |                                                                                                                                 |
# | 45 | Autotrophic Respiration Carbon Flux                              | "Autotrophic Respiration"                                                                                                       |
# | 46 | kinematic flux component                                         |                                                                                                                                 |
# | 47 | water flux                                                       |                                                                                                                                 |
# | 48 | Respiration Carbon Flux                                          | "Total Respiration", "Respiration"                                                                                              |
# | 49 | Dissolution Carbon Flux                                          |                                                                                                                                 |
# | 50 | mean momentum flux                                               |                                                                                                                                 |
# | 51 | net ecosystem exchange carbon flux standard error                |                                                                                                                                 |
# | 52 | carbon flux linear fit slope                                     |                                                                                                                                 |
# | 53 | Net Primary Production Biomass Flux                              |                                                                                                                                 |
# | 54 | Annual Net Primary Productivity Flux                             | "Annual Net Primary Productivity", "Annual Net Primary Production", "ANPP", "anpp", "Annual NPP"                                |
# | 55 | dark respiration carbon flux                                     |                                                                                                                                 |
# | 56 | heat storage flux in air                                         |                                                                                                                                 |
# | 57 | Net Assimilation Rate Flux                                       |                                                                                                                                 |
# | 58 | sensible heat flux without storage correction                    |                                                                                                                                 |
# | 59 | Net Primary Production Carbon Flux                               | "Net Primary Productivity", "Net primary productivity", "Net Primary Production", "NPP"                                         |
# | 60 | soil carbon dioxide flux standard error                          | "soil CO2 standard error"                                                                                                       |
# | 61 | Soil Heterotrophic Respiration Carbon Flux                       |                                                                                                                                 |
# | 62 | Dissolved Organic Carbon Flux                                    |                                                                                                                                 |
# | 63 | correlation coefficient for exponential fit of soil carbon flux  |                                                                                                                                 |
# | 64 | Specific Net Production Flux                                     |                                                                                                                                 |
# | 65 | correlation coefficient for linear fit of soil carbon flux       |                                                                                                                                 |
# | 66 | sensible heat flux                                               |                                                                                                                                 |
# | 67 | correction factor for moisture flux                              |                                                                                                                                 |
# | 68 | water vapor flux                                                 |                                                                                                                                 |
# +----+------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------+

# %%
params['q'] = "flux"
response = requests.get(bio_url, params=params)
print(f"Search for: \"{params['q']}\"")
print(getResultsAscTable(response))
# Out:
# Search for: "flux"
# +----+------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------+
# | #  | prefLabel                                                        | Synonyms                                                                                                                        |
# +----+------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------+
# | 0  | Flux Measurement Type                                            | "Flow Measurement Type"                                                                                                         |
# | 1  | Radiative flux                                                   | "Energy Flux", "Flux"                                                                                                           |
# | 2  | Carbon Dioxide Flux                                              | "CO2 Flux"                                                                                                                      |
# | 3  | Carbon Dioxide Diffusion Flux                                    | "CO2 Diffusion Flux"                                                                                                            |
# | 4  | Marine Macroalgae Net Primary Production Carbon Flux             | "Marine Macroalgae NPP Carbon Flux"                                                                                             |
# | 5  | outgoing photosynthetically active radiation                     | "reflected PAR", "outgoing photosynthetic photon flux density", "reflected photosynthetically active radiation", "outgoing PAR" |
# | 6  | Ground Heat Flux                                                 | "soil heat flux"                                                                                                                |
# | 7  | gap-filled or measured carbon dioxide flux                       | "gap-filled or measured CO2 flux"                                                                                               |
# | 8  | incoming photosynthetically active radiation                     | "incoming PAR", "incoming photosynthetic photon flux density"                                                                   |
# | 9  | Aboveground Net Primary Production Carbon Flux                   | "Aboveground NPP Carbon Flux"                                                                                                   |
# | 10 | Methane Flux                                                     | "CH4 Flux"                                                                                                                      |
# | 11 | Oceanic Carbon Dioxide Flux                                      | "Oceanic CO2 Flux"                                                                                                              |
# | 12 | soil carbon dioxide flux                                         | "soil CO2 flux"                                                                                                                 |
# | 13 | Grassland Above Ground Net Primary Production Carbon Flux        | "Grassland Above Ground NPP Carbon Flux", "anpp"                                                                                |
# | 14 | photosynthetically active radiation                              | "photosynthetic photon flux density", "PAR"                                                                                     |
# | 15 | correction factor for carbon dioxide flux                        | "correction factor for CO2 flux"                                                                                                |
# | 16 | Carbon Flux                                                      | "Mass Flux"                                                                                                                     |
# | 17 | Primary Production Carbon Flux                                   | "Primary production", "Primary productivity", "primary productivity"                                                            |
# | 18 | Specific Gross Production Flux                                   |                                                                                                                                 |
# | 19 | carbon flux standard error                                       |                                                                                                                                 |
# | 20 | momentum flux mean error                                         |                                                                                                                                 |
# | 21 | kinematic flux                                                   |                                                                                                                                 |
# | 22 | Net Ecosystem Exchange Carbon Flux                               | "Net Ecosystem Exchange", "NEE"                                                                                                 |
# | 23 | nitrous oxide flux                                               |                                                                                                                                 |
# | 24 | Momentum Flux                                                    | "tau"                                                                                                                           |
# | 25 | sediment flux                                                    |                                                                                                                                 |
# | 26 | Net Carbon Respiration Rate Flux                                 |                                                                                                                                 |
# | 27 | Latent Heat Flux                                                 |                                                                                                                                 |
# | 28 | Gross Primary Production Carbon Flux                             | "GPP", "Gross primary productivity", "Gross Primary Production", "Gross Primary Productivity"                                   |
# | 29 | Fire Carbon Flux                                                 | "Fire Emissions"                                                                                                                |
# | 30 | Phytoplankton Primary Production Carbon Flux                     | "phytoplankton primary productivity"                                                                                            |
# | 31 | luminous flux                                                    |                                                                                                                                 |
# | 32 | coefficient of variation of exponential fit for soil carbon flux |                                                                                                                                 |
# | 33 | latent heat turbulent flux                                       |                                                                                                                                 |
# | 34 | coefficient of variation of linear fit for soil carbon flux      |                                                                                                                                 |
# | 35 | vertical salt flux                                               |                                                                                                                                 |
# | 36 | momentum flux uncertainty                                        |                                                                                                                                 |
# | 37 | latent heat storage flux                                         |                                                                                                                                 |
# | 38 | carbon flux exponential fit slope                                |                                                                                                                                 |
# | 39 | respiration carbon flux standard error                           |                                                                                                                                 |
# | 40 | Specific Respiration Flux                                        |                                                                                                                                 |
# | 41 | Heterotrophic Respiration Carbon Flux                            | "Heterotrophic Respiration"                                                                                                     |
# | 42 | carbon monoxide flux                                             |                                                                                                                                 |
# | 43 | net ecosystem exchange carbon flux standard deviation            |                                                                                                                                 |
# | 44 | Specific Flux                                                    |                                                                                                                                 |
# | 45 | Autotrophic Respiration Carbon Flux                              | "Autotrophic Respiration"                                                                                                       |
# | 46 | kinematic flux component                                         |                                                                                                                                 |
# | 47 | water flux                                                       |                                                                                                                                 |
# | 48 | Respiration Carbon Flux                                          | "Total Respiration", "Respiration"                                                                                              |
# | 49 | Dissolution Carbon Flux                                          |                                                                                                                                 |
# | 50 | mean momentum flux                                               |                                                                                                                                 |
# | 51 | net ecosystem exchange carbon flux standard error                |                                                                                                                                 |
# | 52 | carbon flux linear fit slope                                     |                                                                                                                                 |
# | 53 | Net Primary Production Biomass Flux                              |                                                                                                                                 |
# | 54 | Annual Net Primary Productivity Flux                             | "Annual Net Primary Productivity", "Annual Net Primary Production", "ANPP", "anpp", "Annual NPP"                                |
# | 55 | dark respiration carbon flux                                     |                                                                                                                                 |
# | 56 | heat storage flux in air                                         |                                                                                                                                 |
# | 57 | Net Assimilation Rate Flux                                       |                                                                                                                                 |
# | 58 | sensible heat flux without storage correction                    |                                                                                                                                 |
# | 59 | Net Primary Production Carbon Flux                               | "Net Primary Productivity", "Net primary productivity", "Net Primary Production", "NPP"                                         |
# | 60 | soil carbon dioxide flux standard error                          | "soil CO2 standard error"                                                                                                       |
# | 61 | Soil Heterotrophic Respiration Carbon Flux                       |                                                                                                                                 |
# | 62 | Dissolved Organic Carbon Flux                                    |                                                                                                                                 |
# | 63 | correlation coefficient for exponential fit of soil carbon flux  |                                                                                                                                 |
# | 64 | Specific Net Production Flux                                     |                                                                                                                                 |
# | 65 | correlation coefficient for linear fit of soil carbon flux       |                                                                                                                                 |
# | 66 | sensible heat flux                                               |                                                                                                                                 |
# | 67 | correction factor for moisture flux                              |                                                                                                                                 |
# | 68 | water vapor flux                                                 |                                                                                                                                 |
# +----+------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------+

# %%
url = ""
